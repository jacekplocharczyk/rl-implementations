# %%
import argparse
import gym
import numpy as np
from itertools import count

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical


# parser = argparse.ArgumentParser(description='PyTorch REINFORCE example')
# parser.add_argument('--gamma', type=float, default=0.99, metavar='G',
#                     help='discount factor (default: 0.99)')
# parser.add_argument('--seed', type=int, default=543, metavar='N',
#                     help='random seed (default: 543)')
# parser.add_argument('--render', action='store_true',
#                     help='render the environment')
# parser.add_argument('--log-interval', type=int, default=10, metavar='N',
#                     help='interval between training status logs (default: 10)')
# args = parser.parse_args()

class args:
    seed = 12331 
    seed = 12335

    gamma = 0.9
    render = True
    log_interval = 10



env = gym.make('CartPole-v1')
env.seed(args.seed)
torch.manual_seed(args.seed)


class Policy(nn.Module):
    def __init__(self):
        super(Policy, self).__init__()
        self.affine1 = nn.Linear(4, 128)
        self.dropout = nn.Dropout(p=0.6)
        self.affine2 = nn.Linear(128, 2)

        self.saved_log_probs = []
        self.rewards = []

    def forward(self, x):
        x = self.affine1(x)
        x = self.dropout(x)
        x = F.relu(x)
        action_scores = self.affine2(x)
        return F.softmax(action_scores, dim=1)


policy = Policy()
optimizer = optim.Adam(policy.parameters(), lr=1e-2)
eps = np.finfo(np.float32).eps.item()


def select_action(state):
    state = torch.from_numpy(state).float().unsqueeze(0)
    probs = policy(state)
    m = Categorical(probs)
    action = m.sample()
    policy.saved_log_probs.append(m.log_prob(action))
    return action.item()


def finish_episode():
    R = 0
    policy_loss = []
    returns = []
    for r in policy.rewards[::-1]:
        R = r + args.gamma * R
        returns.insert(0, R)
    returns = torch.tensor(returns)
    returns = (returns - returns.mean()) / (returns.std() + eps)  # noramlization
    for log_prob, R in zip(policy.saved_log_probs, returns):
        policy_loss.append(-log_prob * R)
    optimizer.zero_grad()
    policy_loss = torch.cat(policy_loss).sum()
    policy_loss.backward()
    optimizer.step()
    del policy.rewards[:]
    del policy.saved_log_probs[:]


def main():
    running_reward = 10
    for i_episode in count(1):
        state, ep_reward = env.reset(), 0
        for t in range(1, 10000):  # Don't infinite loop while learning
            action = select_action(state)
            state, reward, done, _ = env.step(action)
            if args.render:
                env.render()
            policy.rewards.append(reward)
            ep_reward += reward
            if done:
                break

        running_reward = 0.05 * ep_reward + (1 - 0.05) * running_reward
        finish_episode()
        if i_episode % args.log_interval == 0:
            print('Episode {}\tLast reward: {:.2f}\tAverage reward: {:.2f}'.format(
                  i_episode, ep_reward, running_reward))
        if running_reward > env.spec.reward_threshold:
            print("Solved! Running reward is now {} and "
                  "the last episode runs to {} time steps!".format(running_reward, t))
            break


if __name__ == '__main__':
    main()
# Out:
# Episode 10	Last reward: 14.00	Average reward: 12.48
# Episode 20	Last reward: 18.00	Average reward: 14.22
# Episode 30	Last reward: 36.00	Average reward: 17.37
# Episode 40	Last reward: 63.00	Average reward: 22.20
# Episode 50	Last reward: 48.00	Average reward: 33.76
# Episode 60	Last reward: 226.00	Average reward: 63.94
# Episode 70	Last reward: 65.00	Average reward: 80.07
# Episode 80	Last reward: 240.00	Average reward: 135.91
# Episode 90	Last reward: 120.00	Average reward: 129.80
# Episode 100	Last reward: 307.00	Average reward: 150.21
# Episode 110	Last reward: 255.00	Average reward: 212.71
# Episode 120	Last reward: 147.00	Average reward: 201.00
# Episode 130	Last reward: 224.00	Average reward: 182.63
# Episode 140	Last reward: 150.00	Average reward: 175.82
# Episode 150	Last reward: 152.00	Average reward: 171.96
# Episode 160	Last reward: 127.00	Average reward: 173.53
# Episode 170	Last reward: 64.00	Average reward: 142.39
# Episode 180	Last reward: 77.00	Average reward: 110.24
# Episode 190	Last reward: 96.00	Average reward: 94.00
# Episode 200	Last reward: 160.00	Average reward: 112.72
# Episode 210	Last reward: 212.00	Average reward: 162.45
# Episode 220	Last reward: 283.00	Average reward: 196.76
# Episode 230	Last reward: 500.00	Average reward: 318.44
# Episode 240	Last reward: 303.00	Average reward: 360.87
# Episode 250	Last reward: 155.00	Average reward: 298.61
# Episode 260	Last reward: 25.00	Average reward: 221.18
# Episode 270	Last reward: 151.00	Average reward: 179.05
# Episode 280	Last reward: 140.00	Average reward: 169.66
# Episode 290	Last reward: 132.00	Average reward: 147.78
# Episode 300	Last reward: 136.00	Average reward: 135.74
# Episode 310	Last reward: 142.00	Average reward: 136.61
# Episode 320	Last reward: 200.00	Average reward: 153.59
# Episode 330	Last reward: 211.00	Average reward: 167.15
# Episode 340	Last reward: 145.00	Average reward: 167.05
# Episode 350	Last reward: 142.00	Average reward: 164.67
# Episode 360	Last reward: 196.00	Average reward: 177.86
# Episode 370	Last reward: 255.00	Average reward: 204.21
# Episode 380	Last reward: 279.00	Average reward: 228.29
# Episode 390	Last reward: 311.00	Average reward: 266.73
# Episode 400	Last reward: 149.00	Average reward: 246.15
# Episode 410	Last reward: 139.00	Average reward: 206.06
# Episode 420	Last reward: 55.00	Average reward: 160.49
# Episode 430	Last reward: 38.00	Average reward: 118.07
# Episode 440	Last reward: 53.00	Average reward: 96.31
# Episode 450	Last reward: 97.00	Average reward: 89.05
# Episode 460	Last reward: 105.00	Average reward: 100.11
# Episode 470	Last reward: 139.00	Average reward: 106.31
# Episode 480	Last reward: 136.00	Average reward: 115.90
# Episode 490	Last reward: 172.00	Average reward: 132.68
# Episode 500	Last reward: 170.00	Average reward: 159.40
# Episode 510	Last reward: 277.00	Average reward: 192.31
# Episode 520	Last reward: 458.00	Average reward: 264.39
# Episode 530	Last reward: 327.00	Average reward: 296.10
# Episode 540	Last reward: 500.00	Average reward: 334.43
# Episode 550	Last reward: 500.00	Average reward: 388.94
# Episode 560	Last reward: 500.00	Average reward: 433.50
# Episode 570	Last reward: 283.00	Average reward: 398.35
# Episode 580	Last reward: 205.00	Average reward: 330.37
# Episode 590	Last reward: 216.00	Average reward: 281.73
# Episode 600	Last reward: 225.00	Average reward: 260.72
# Episode 610	Last reward: 222.00	Average reward: 240.67
# Episode 620	Last reward: 249.00	Average reward: 233.07
# Episode 630	Last reward: 208.00	Average reward: 231.44
# Episode 640	Last reward: 500.00	Average reward: 280.41
# Episode 650	Last reward: 466.00	Average reward: 350.30
# Episode 660	Last reward: 219.00	Average reward: 343.82
# Episode 670	Last reward: 267.00	Average reward: 296.51
# Episode 680	Last reward: 238.00	Average reward: 270.53
# Episode 690	Last reward: 233.00	Average reward: 243.75
# Episode 700	Last reward: 217.00	Average reward: 242.71
# Episode 710	Last reward: 192.00	Average reward: 232.30
# Episode 720	Last reward: 254.00	Average reward: 229.31
# Episode 730	Last reward: 196.00	Average reward: 230.82
# Episode 740	Last reward: 247.00	Average reward: 237.63
# Episode 750	Last reward: 305.00	Average reward: 277.73
# Episode 760	Last reward: 380.00	Average reward: 324.74
# Episode 770	Last reward: 226.00	Average reward: 322.82
# Episode 780	Last reward: 500.00	Average reward: 343.58
# Episode 790	Last reward: 500.00	Average reward: 405.59
# Episode 800	Last reward: 406.00	Average reward: 438.77
# Episode 810	Last reward: 500.00	Average reward: 463.34
# Solved! Running reward is now 475.67951081384086 and the last episode runs to 500 time steps!
